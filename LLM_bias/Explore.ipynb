# %%
import json

# %%
json_data = [] # your list with json objects (dicts)

with open('dataset/nobel_laureates.json') as json_file:
   json_data = json.load(json_file)

# %%
json_data[0]
# Out:
# {'id': 314,
#  'firstname': 'John',
#  'surname': 'Macleod',
#  'born': '1876-09-06',
#  'died': '1935-03-16',
#  'borncountry': 'Scotland',
#  'borncountrycode': 'GB',
#  'borncity': 'Cluny',
#  'diedcountry': 'Scotland',
#  'diedcountrycode': 'GB',
#  'diedcity': 'Aberdeen',
#  'gender': 'male',
#  'year': '1923',
#  'category': 'Medicine',
#  'overallmotivation': None,
#  'motivation': '"for the discovery of insulin"',
#  'name': 'University of Toronto',
#  'city': 'Toronto',
#  'country': 'Canada',
#  'geo_shape': {'type': 'Feature',
#   'geometry': {'coordinates': [[[[-65.61058509, 43.428168036],
#       [-65.628814257, 43.42206452],
#       [-65.621408658, 43.435044664],
#       [-65.626942512, 43.445135809],
#       [-65.656117317, 43.463039455],
#       [-65.607777473, 43.483465887],
#       [-65.617054817, 43.50787995],
#       [-65.605213996, 43.514105536],
#       [-65.559925911, 43.510809637],
#       [-65.574208137, 43.47671133],
#       [-65.61058509, 43.428168036]]],
# ...

# %%
import pandas as pd
df = pd.read_csv("dataset/country_raw.csv")

# %%
df["leader_position"].unique()
# Out:
# array(['Prime Minister', 'President', 'General Secretary of the HDK',
#        'President/General Secretary of the HDK', 'de facto ruler',
#        'Chairman of the Interim Administration', 'First Secretary',
#        'First Secretary/Chairman of the Council of Ministers', nan,
#        'Chancellor', 'Emir', 'King', 'Chairman of the Supreme Soviet',
#        'Chairman of the Directory', 'Chairman of the Military Junta',
#        'President of the Plurinational State',
#        'Chairman of the State Presidency',
#        'Chairman of the Presidency of the Republic', 'Sultan', 'Premier',
#        'Chairman of Party the of Socialist Programme of Burma',
#        'Chairman of the State Law and Order Restoration Council',
#        'Chairman of the State Peace and Development Council',
#        'State Counselor', 'State Counsellor', 'unknown', 'Head of State',
#        'PM/Secretary-general of KCP',
#        "President of the People's Revolutionary Council",
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10992 entries, 0 to 10991
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country_name               10992 non-null  object
#  1   country_code_cow           10992 non-null  int64
#  2   year                       10992 non-null  int64
#  3   hog                        10727 non-null  object
#  4   hog_ideology               10992 non-null  object
#  5   hog_ideology_num_full      10727 non-null  object
#  6   hog_ideology_num_redux     10727 non-null  object
#  7   hog_right                  10727 non-null  float64
#  8   hog_left                   10727 non-null  float64
#  9   hog_center                 10727 non-null  float64
#  10  hog_noideo                 10727 non-null  float64
#  11  hog_noinfo                 10727 non-null  float64
#  12  hog_ideomiss               10727 non-null  float64
# ...

# %%
columns = ["country_name", "year", "leader", "leader_position"]
